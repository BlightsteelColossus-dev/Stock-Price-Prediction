# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential, load_model
from keras.layers import LSTM, Dense, Dropout

# %%
df = pd.read_csv("NSE-TATA.csv")

# %%
df.shape
# Out:
# (1235, 8)

# %%
dataset_train = np.array(df[:int(df.shape[0]*0.8)])
dataset_test = np.array(df[int(df.shape[0]*0.8):])

# %%
scaler = MinMaxScaler(feature_range=(0,1))
dataset_train = scaler.fit_transform(dataset_train)
dataset_test = scaler.transform(dataset_test)

# %%
def create_dataset(df):
    x = []
    y = []
    for i in range(50, df.shape[0]):
        x.append(df[i-50:i, 0])
        y.append(df[i, 0])
    x = np.array(x)
    y = np.array(y)
    return x,y

# %%
x_train, y_train = create_dataset(dataset_train)
x_test, y_test = create_dataset(dataset_test)

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
model = Sequential()
model.add(LSTM(units=96, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=96,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=96,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=96))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.fit(x_train, y_train, epochs=50, batch_size=32)
model.save('stock_prediction.h5')
# Out:
# Epoch 1/50
# 30/30 [==============================] - 6s 70ms/step - loss: 0.0286
# Epoch 2/50
# 30/30 [==============================] - 2s 63ms/step - loss: 0.0059: 0s
# Epoch 3/50
# 30/30 [==============================] - 2s 64ms/step - loss: 0.0043 ETA: 0s - loss:
# Epoch 4/50
# 30/30 [==============================] - 2s 62ms/step - loss: 0.0042: 0s - loss:
# Epoch 5/50
# 30/30 [==============================] - 2s 62ms/step - loss: 0.0041: 1s - loss: 0. - ETA: 0s -
# Epoch 6/50
# 30/30 [==============================] - 2s 62ms/step - loss: 0.0041
# Epoch 7/50
# 30/30 [==============================] - 2s 62ms/step - loss: 0.0033
# Epoch 8/50
# 30/30 [==============================] - 2s 62ms/step - loss: 0.0040
# Epoch 9/50
# 30/30 [==============================] - 2s 80ms/step - loss: 0.0032
# Epoch 10/50
# 30/30 [==============================] - 2s 70ms/step - loss: 0.0034: 1s
# Epoch 11/50
# 30/30 [==============================] - 2s 63ms/step - loss: 0.0028: 0s - loss: 0. - ETA: 0s - loss:
# Epoch 12/50
# 30/30 [==============================] - 2s 63ms/step - loss: 0.0032
# Epoch 13/50
# 30/30 [==============================] - 2s 63ms/step - loss: 0.0028
# Epoch 14/50
# 30/30 [==============================] - 2s 64ms/step - loss: 0.0036
# Epoch 15/50
# 30/30 [==============================] - 2s 68ms/step - loss: 0.0028
# Epoch 16/50
# 30/30 [==============================] - 2s 64ms/step - loss: 0.0023
# Epoch 17/50
# 30/30 [==============================] - 2s 65ms/step - loss: 0.0026
# Epoch 18/50
# 30/30 [==============================] - 2s 64ms/step - loss: 0.0023
# Epoch 19/50
# 30/30 [==============================] - 2s 65ms/step - loss: 0.0026
# Epoch 20/50
# 30/30 [==============================] - 2s 65ms/step - loss: 0.0025: 1s - ETA: 0s - loss: 0.00
# Epoch 21/50
# 30/30 [==============================] - 2s 64ms/step - loss: 0.0019: 0s -
# Epoch 22/50
# 30/30 [==============================] - 2s 65ms/step - loss: 0.0023
# Epoch 23/50
# 30/30 [==============================] - 2s 66ms/step - loss: 0.0022
# Epoch 24/50
# 30/30 [==============================] - 2s 65ms/step - loss: 0.0020
# Epoch 25/50
# 30/30 [==============================] - 2s 65ms/step - loss: 0.0020: 0s - loss
# Epoch 26/50
# 30/30 [==============================] - 2s 65ms/step - loss: 0.0027
# Epoch 27/50
# 30/30 [==============================] - 2s 66ms/step - loss: 0.0023: 0s - loss: 0.00
# Epoch 28/50
# 30/30 [==============================] - 2s 66ms/step - loss: 0.0018
# Epoch 29/50
# 30/30 [==============================] - 2s 67ms/step - loss: 0.0019
# Epoch 30/50
# 30/30 [==============================] - 2s 65ms/step - loss: 0.0019
# Epoch 31/50
# 30/30 [==============================] - 2s 65ms/step - loss: 0.0019
# Epoch 32/50
# 30/30 [==============================] - 2s 65ms/step - loss: 0.0018
# Epoch 33/50
# 30/30 [==============================] - 2s 66ms/step - loss: 0.0019: 0s - loss: 0.
# Epoch 34/50
# 30/30 [==============================] - 2s 66ms/step - loss: 0.0016
# Epoch 35/50
# 30/30 [==============================] - 2s 72ms/step - loss: 0.0018
# Epoch 36/50
# 30/30 [==============================] - 2s 68ms/step - loss: 0.0017
# Epoch 37/50
# 30/30 [==============================] - 2s 72ms/step - loss: 0.0017
# Epoch 38/50
# 30/30 [==============================] - 2s 72ms/step - loss: 0.0015
# Epoch 39/50
# 30/30 [==============================] - 2s 66ms/step - loss: 0.0014
# Epoch 40/50
# 30/30 [==============================] - 2s 70ms/step - loss: 0.0015
# Epoch 41/50
# 30/30 [==============================] - 2s 63ms/step - loss: 0.0020
# Epoch 42/50
# 30/30 [==============================] - 2s 62ms/step - loss: 0.0020
# Epoch 43/50
# 30/30 [==============================] - 2s 64ms/step - loss: 0.0015
# Epoch 44/50
# 30/30 [==============================] - 2s 63ms/step - loss: 0.0015
# Epoch 45/50
# 30/30 [==============================] - 2s 62ms/step - loss: 0.0016
# Epoch 46/50
# 30/30 [==============================] - 2s 62ms/step - loss: 0.0018
# Epoch 47/50
# 30/30 [==============================] - 2s 63ms/step - loss: 0.0016: 0s - loss: 0 - ETA: 0s - loss: 0.
# Epoch 48/50
# 30/30 [==============================] - 2s 63ms/step - loss: 0.0014
# Epoch 49/50
# 30/30 [==============================] - 2s 62ms/step - loss: 0.0015: 0s - l
# Epoch 50/50
# 30/30 [==============================] - 2s 63ms/step - loss: 0.0016: 0s - loss: 0.001

# %%
model = load_model('stock_prediction.h5')

# %%
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)
y_test_scaled = scaler.inverse_transform(y_test.reshape(-1, 1))

fig, ax = plt.subplots(figsize=(16,8))
ax.set_facecolor('#000041')
ax.plot(y_test_scaled, color='red', label='Original price')
plt.plot(predictions, color='cyan', label='Predicted price')
plt.legend()
